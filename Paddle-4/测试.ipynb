# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg 

# 待预测图片
test_img_path = ['/Jupyter/Paddle/Paddle-3/test/1.jpg']
img = mpimg.imread(test_img_path[0]) 

# 展示待预测图片
plt.figure(figsize=(10,10))
plt.imshow(img) 
plt.axis('off') 
plt.show()

# %%
with open('test/test.txt', 'r') as f:
    test_img_path=[]
    for line in f:
        test_img_path.append(line.strip())
print(test_img_path)
# Out:
# ['/home/aistudio/test/1.jpg']

# %%
import paddlehub as hub

module = hub.Module(name="pyramidbox_lite_mobile_mask")
# module = hub.Module(name="pyramidbox_lite_server_mask")
# Out:
# [2020-04-05 03:41:07,431] [    INFO] - Installing pyramidbox_lite_mobile_mask module
# [2020-04-05 03:41:07,462] [    INFO] - Module pyramidbox_lite_mobile_mask already installed in C:\Users\25003\.paddlehub\modules\pyramidbox_lite_mobile_mask
# [2020-04-05 03:41:07,803] [    INFO] - Installing pyramidbox_lite_mobile module
# [2020-04-05 03:41:07,840] [    INFO] - Module pyramidbox_lite_mobile already installed in C:\Users\25003\.paddlehub\modules\pyramidbox_lite_mobile

# %%
input_dict = {"image": test_img_path}

# 口罩检测预测
results = module.face_detection(data=input_dict)
for result in results:
    print(result)

# 预测结果展示
img = mpimg.imread("detection_result/1.jpg")
plt.figure(figsize=(10,10))
plt.imshow(img) 
plt.axis('off') 
plt.show()
# Out:
# [2020-04-05 03:41:09,731] [    INFO] - 133 pretrained paramaters loaded by PaddleHub
# [2020-04-05 03:41:09,804] [    INFO] - 149 pretrained paramaters loaded by PaddleHub
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-c2b8f32cc681> in <module>
#       2
#       3 # 口罩检测预测
# ----> 4 results = module.face_detection(data=input_dict)
#       5 for result in results:
#       6     print(result)
#
# D:\Anaconda3\envs\Paddle\lib\site-packages\paddlehub\module\module.py in __call__(self, sign_name, data, use_gpu, batch_size, **kwargs)
#     556             exe = fluid.Executor(place=place)
#     557             data = self.processor.preprocess(
# --> 558                 sign_name=sign_name, data_dict=data)
#     559             data_format = self.processor.data_format(sign_name=sign_name)
#     560             reader, feeder = _get_reader_and_feeder(data_format, data, place)
#
# ~\.paddlehub\modules\pyramidbox_lite_mobile_mask\python\3e235e329706d8e7205ebee1b9284f92.py in preprocess(self, sign_name, data_dict)
#     248                 det_results[index]['data'] = faces
#     249         else:
# --> 250             det_results = self.face_detector.face_detection(data=data_dict, visualization=False, use_gpu=use_gpu, batch_size=batch_size, shrink=shrink)
#     251
#     252         for data_id, det_result in enumerate(det_results):
#
# D:\Anaconda3\envs\Paddle\lib\site-packages\paddlehub\module\module.py in __call__(self, sign_name, data, use_gpu, batch_size, **kwargs)
#     556             exe = fluid.Executor(place=place)
#     557             data = self.processor.preprocess(
# --> 558                 sign_name=sign_name, data_dict=data)
#     559             data_format = self.processor.data_format(sign_name=sign_name)
#     560             reader, feeder = _get_reader_and_feeder(data_format, data, place)
#
# ~\.paddlehub\modules\pyramidbox_lite_mobile\python\0f609e894acb291bb0f83290cda4cdea.py in preprocess(self, sign_name, data_dict)
#     100                 result_i = {}
#     101                 orig_image = cv2.imread(path)
# --> 102                 data, height, width = process_image(orig_image, shrink)
#     103                 result_i['id'] = data_id
#     104                 result_i['path'] = path
#
# ~\.paddlehub\modules\pyramidbox_lite_mobile\python\0f609e894acb291bb0f83290cda4cdea.py in process_image(orig_image, shrink)
#      73         shrink = kwargs.get('shrink', self.shrink)
#      74         def process_image(orig_image, shrink):
# ---> 75             image = Image.fromarray(orig_image[:,:,::-1])
#      76             if image.mode == 'L':
#      77                 image = image.convert('RGB')
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# !hub search resnet
# Out:
# +----------------------+----------+----------+----------------------+
# |     ResourceName     |   Type   | Version  |       Summary        |
# +----------------------+----------+----------+----------------------+
# |resnet_v2_50_imagene  |  Module  |  1.0.1   |ResNet50 is a image   |
# |t                     |          |          |classfication model   |
# |                      |          |          |trained with ImageNe  |
# |                      |          |          |t-2012 dataset.       |
# +----------------------+----------+----------+----------------------+
# |resnet_v2_34_imagene  |  Module  |  1.0.0   |ResNet34 is a image   |
# |t                     |          |          |classfication model   |
# |                      |          |          |trained with ImageNe  |
# |                      |          |          |t-2012 dataset.       |
# +----------------------+----------+----------+----------------------+
# |resnet_v2_18_imagene  |  Module  |  1.0.0   |ResNet18 is a image   |
# |t                     |          |          |classfication model   |
# |                      |          |          |trained with ImageNe  |
# |                      |          |          |t-2012 dataset.       |
# +----------------------+----------+----------+----------------------+
# |resnet_v2_152_imagen  |  Module  |  1.0.1   |ResNet152 is a image  |
# |et                    |          |          | classfication model  |
# |                      |          |          | trained with ImageN  |
# |                      |          |          |et-2012 dataset.      |
# +----------------------+----------+----------+----------------------+
# |resnet_v2_101_imagen  |  Module  |  1.0.1   |ResNet101 is a image  |
# |et                    |          |          | classfication model  |
# |                      |          |          | trained with ImageN  |
# |                      |          |          |et-2012 dataset.      |
# +----------------------+----------+----------+----------------------+
